# %% [markdown]
# # Scraping the AVB for PDFs of bulletins

# %%
import os
import re
import time
import sys

import requests

# %% [markdown]
# ## Fonctions

# %%
def get_urls():
    """Retrieve all URLs from root AVB page"""
    root_url = "https://archives.bruxelles.be/bulletins/date"
    resp = requests.get(root_url)
    print(f"Status: {resp.status_code}")
    print(f"Encoding: {resp.encoding}")
    html = resp.text
    print(f"Text length: {len(html)}")

    pattern = r"https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/.*\.pdf"
    urls = re.findall(pattern, html)
    print(f"{len(urls)} PDF files found")
    return urls

# %%
def download(pdf_path, urls, offset=0):
    """Dowloading all files starting from offset"""
    for url in urls[offset:]:
        filename = url.split("/")[-1]
        print(f"Dowloading {filename}...")
        start_time = time.time()
        response = requests.get(url)
        print(f"   done in {(time.time() - start_time):.1f} seconds")
        with open(f"{pdf_path}/{filename}", 'wb') as f:
            f.write(response.content)

# %%
def check(pdf_path, urls):
    """Check if all files have been downloaded"""
    ok_count = 0
    for url in urls:
        filename = url.split("/")[-1]
        downloads = os.listdir(pdf_path)
        if filename not in downloads:
            print(f"{filename} is missing!")
        else:
            ok_count += 1
    print(f"{ok_count} PDFs found on {len(urls)}!")

# %% [markdown]
# ## Obtenir les URLs des bulletins communaux

# %%
urls = get_urls()
# Out:
# Status: 200
# Encoding: utf-8
# Text length: 821431
# 2833 PDF files found

# %%
len(urls)
# Out:
# 2833

# %%
urls[:6]
# Out:
# ['https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1847_Tome_I1_Part_1.pdf',
#  'https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1847_Tome_I1_Part_2.pdf',
#  'https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1847_Tome_I1_Part_3.pdf',
#  'https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1847_Tome_I1_Part_4.pdf',
#  'https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1847_Tome_I1_Part_5.pdf',
#  'https://archief.brussel.be/Colossus/BulletinsCommunaux/Bulletins/Documents/Bxl_1848_Tome_I1_Part_1.pdf']

# %% [markdown]
# ## Créer un dossier `data/pdf` s'il n'existe pas

# %%
pdf_path = '../data/pdf'

# %%
from pathlib import Path

Path(pdf_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Télécharger les 3 premiers PDFs

# %%
# %%time
download(pdf_path, urls[:700])
# Out:
# df...
#    done in 2.0 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_3.pdf...
#    done in 2.1 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_4.pdf...
#    done in 2.0 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_5.pdf...
#    done in 1.9 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_6.pdf...
#    done in 2.0 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_7.pdf...
#    done in 2.4 seconds
# Dowloading Lkn_1882_Tome_RptAn_Part_8.pdf...
#    done in 1.8 seconds
# Dowloading Bxl_1883_Tome_I1_Part_1.pdf...
#    done in 19.8 seconds
# Dowloading Bxl_1883_Tome_I1_Part_2.pdf...
#    done in 19.2 seconds
# Dowloading Bxl_1883_Tome_I1_Part_3.pdf...
#    done in 19.8 seconds
# Dowloading Bxl_1883_Tome_I1_Part_4.pdf...
#    done in 25.2 seconds
# Dowloading Bxl_1883_Tome_I1_Part_5.pdf...
#    done in 15.0 seconds
# Dowloading Bxl_1883_Tome_I1_Part_6.pdf...
#    done in 14.1 seconds
# Dowloading Bxl_1883_Tome_I1_Part_7.pdf...
#    done in 4.2 seconds
# Dowloading Bxl_1883_Tome_I2_Part_1.pdf...
#    done in 15.0 seconds
# Dowloading Bxl_1883_Tome_I2_Part_10.pdf...
#    done in 13.6 seconds
# Dowloading Bxl_1883_Tome_I2_Part_11.pdf...
#    done in 17.6 seconds
# Dowloading Bxl_1883_Tome_I2_Part_12.pdf...
#    done in 3.0 seconds
# Dowloading Bxl_1883_Tome_I2_Part_2.pdf...
#    done in 15.3 seconds
# Dowloading Bxl_1883_Tome_I2_Part_3.pdf...
#    done in 11.9 seconds
# Dowloading Bxl_1883_Tome_I2_Part_4.pdf...
#    done in 13.6 seconds
# Dowloading Bxl_1883_Tome_I2_Part_5.pdf...
#    done in 13.4 seconds
# Dowloading Bxl_1883_Tome_I2_Part_6.pdf...
#    done in 12.0 seconds
# Dowloading Bxl_1883_Tome_I2_Part_7.pdf...
#    done in 11.6 seconds
# Dowloading Bxl_1883_Tome_I2_Part_8.pdf...
#    done in 9.9 seconds
# Dowloading Bxl_1883_Tome_I2_Part_9.pdf...
#    done in 12.9 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_1.pdf...
#    done in 8.8 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_2.pdf...
#    done in 10.0 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_3.pdf...
#    done in 10.7 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_4.pdf...
#    done in 8.7 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_5.pdf...
#    done in 9.7 seconds
# Dowloading Lkn_1883_Tome_RptAn_Part_6.pdf...
#    done in 1.5 seconds
# Dowloading Bxl_1884_Tome_I1_Part_1.pdf...
#    done in 12.2 seconds
# Dowloading Bxl_1884_Tome_I1_Part_2.pdf...
#    done in 16.3 seconds
# Dowloading Bxl_1884_Tome_I1_Part_3.pdf...
#    done in 26.2 seconds
# Dowloading Bxl_1884_Tome_I1_Part_4.pdf...
#    done in 36.4 seconds
# Dowloading Bxl_1884_Tome_I1_Part_5.pdf...
#    done in 30.9 seconds
# Dowloading Bxl_1884_Tome_I1_Part_6.pdf...
#    done in 18.8 seconds
# Dowloading Bxl_1884_Tome_I1_Part_7.pdf...
#    done in 5.3 seconds
# Dowloading Bxl_1884_Tome_I2_Part_1.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1884_Tome_I2_Part_10.pdf...
#    done in 2.5 seconds
# Dowloading Bxl_1884_Tome_I2_Part_2.pdf...
#    done in 12.6 seconds
# Dowloading Bxl_1884_Tome_I2_Part_3.pdf...
#    done in 13.6 seconds
# Dowloading Bxl_1884_Tome_I2_Part_4.pdf...
#    done in 14.4 seconds
# Dowloading Bxl_1884_Tome_I2_Part_5.pdf...
#    done in 15.3 seconds
# Dowloading Bxl_1884_Tome_I2_Part_6.pdf...
#    done in 26.3 seconds
# Dowloading Bxl_1884_Tome_I2_Part_7.pdf...
#    done in 10.8 seconds
# Dowloading Bxl_1884_Tome_I2_Part_8.pdf...
#    done in 11.1 seconds
# Dowloading Bxl_1884_Tome_I2_Part_9.pdf...
#    done in 11.3 seconds
# Dowloading Lkn_1884_Tome_I_Part_1.pdf...
#    done in 1.9 seconds
# Dowloading Lkn_1884_Tome_I_Part_2.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1884_Tome_I_Part_3.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1884_Tome_I_Part_4.pdf...
#    done in 1.9 seconds
# Dowloading Lkn_1884_Tome_I_Part_5.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1884_Tome_I_Part_6.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1884_Tome_I_Part_7.pdf...
#    done in 1.6 seconds
# Dowloading Lkn_1884_Tome_I_Part_8.pdf...
#    done in 0.7 seconds
# Dowloading Bxl_1885_Tome_I1_Part_1.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1885_Tome_I1_Part_2.pdf...
#    done in 22.9 seconds
# Dowloading Bxl_1885_Tome_I1_Part_3.pdf...
#    done in 22.5 seconds
# Dowloading Bxl_1885_Tome_I1_Part_4.pdf...
#    done in 20.9 seconds
# Dowloading Bxl_1885_Tome_I1_Part_5.pdf...
#    done in 14.0 seconds
# Dowloading Bxl_1885_Tome_I1_Part_6.pdf...
#    done in 11.0 seconds
# Dowloading Bxl_1885_Tome_I2_Part_1.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1885_Tome_I2_Part_10.pdf...
#    done in 11.8 seconds
# Dowloading Bxl_1885_Tome_I2_Part_11.pdf...
#    done in 11.3 seconds
# Dowloading Bxl_1885_Tome_I2_Part_12.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1885_Tome_I2_Part_13.pdf...
#    done in 17.4 seconds
# Dowloading Bxl_1885_Tome_I2_Part_14.pdf...
#    done in 6.7 seconds
# Dowloading Bxl_1885_Tome_I2_Part_2.pdf...
#    done in 11.7 seconds
# Dowloading Bxl_1885_Tome_I2_Part_3.pdf...
#    done in 8.5 seconds
# Dowloading Bxl_1885_Tome_I2_Part_4.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1885_Tome_I2_Part_5.pdf...
#    done in 11.4 seconds
# Dowloading Bxl_1885_Tome_I2_Part_6.pdf...
#    done in 12.6 seconds
# Dowloading Bxl_1885_Tome_I2_Part_7.pdf...
#    done in 12.4 seconds
# Dowloading Bxl_1885_Tome_I2_Part_8.pdf...
#    done in 11.0 seconds
# Dowloading Bxl_1885_Tome_I2_Part_9.pdf...
#    done in 12.9 seconds
# Dowloading Lkn_1885_Tome_I_Part_1.pdf...
#    done in 14.9 seconds
# Dowloading Lkn_1885_Tome_I_Part_2.pdf...
#    done in 11.7 seconds
# Dowloading Lkn_1885_Tome_I_Part_3.pdf...
#    done in 10.3 seconds
# Dowloading Lkn_1885_Tome_I_Part_4.pdf...
#    done in 8.9 seconds
# Dowloading Lkn_1885_Tome_I_Part_5.pdf...
#    done in 9.5 seconds
# Dowloading Lkn_1885_Tome_I_Part_6.pdf...
#    done in 9.0 seconds
# Dowloading Lkn_1885_Tome_I_Part_7.pdf...
#    done in 9.0 seconds
# Dowloading Lkn_1885_Tome_I_Part_8.pdf...
#    done in 4.9 seconds
# Dowloading Lkn_1885_Tome_RptAn_Part_1.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1885_Tome_RptAn_Part_2.pdf...
#    done in 2.3 seconds
# Dowloading Lkn_1885_Tome_RptAn_Part_3.pdf...
#    done in 1.7 seconds
# Dowloading Lkn_1885_Tome_RptAn_Part_4.pdf...
#    done in 1.5 seconds
# Dowloading Lkn_1885_Tome_RptAn_Part_5.pdf...
#    done in 1.0 seconds
# Dowloading Bxl_1886_Tome_I1_Part_1.pdf...
#    done in 12.9 seconds
# Dowloading Bxl_1886_Tome_I1_Part_2.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1886_Tome_I1_Part_3.pdf...
#    done in 14.0 seconds
# Dowloading Bxl_1886_Tome_I1_Part_4.pdf...
#    done in 55.1 seconds
# Dowloading Bxl_1886_Tome_I1_Part_5.pdf...
#    done in 12.6 seconds
# Dowloading Bxl_1886_Tome_I1_Part_6.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1886_Tome_I1_Part_7.pdf...
#    done in 26.6 seconds
# Dowloading Bxl_1886_Tome_I1_Part_8.pdf...
#    done in 23.8 seconds
# Dowloading Bxl_1886_Tome_I1_Part_9.pdf...
#    done in 14.2 seconds
# Dowloading Bxl_1886_Tome_I2_Part_1.pdf...
#    done in 14.4 seconds
# Dowloading Bxl_1886_Tome_I2_Part_10.pdf...
#    done in 19.7 seconds
# Dowloading Bxl_1886_Tome_I2_Part_11.pdf...
#    done in 16.5 seconds
# Dowloading Bxl_1886_Tome_I2_Part_12.pdf...
#    done in 16.8 seconds
# Dowloading Bxl_1886_Tome_I2_Part_13.pdf...
#    done in 3.5 seconds
# Dowloading Bxl_1886_Tome_I2_Part_2.pdf...
#    done in 8.9 seconds
# Dowloading Bxl_1886_Tome_I2_Part_3.pdf...
#    done in 11.8 seconds
# Dowloading Bxl_1886_Tome_I2_Part_4.pdf...
#    done in 13.0 seconds
# Dowloading Bxl_1886_Tome_I2_Part_5.pdf...
#    done in 12.4 seconds
# Dowloading Bxl_1886_Tome_I2_Part_6.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1886_Tome_I2_Part_7.pdf...
#    done in 12.9 seconds
# Dowloading Bxl_1886_Tome_I2_Part_8.pdf...
#    done in 11.5 seconds
# Dowloading Bxl_1886_Tome_I2_Part_9.pdf...
#    done in 16.8 seconds
# Dowloading Lkn_1886_Tome_I_Part_1.pdf...
#    done in 9.1 seconds
# Dowloading Lkn_1886_Tome_I_Part_2.pdf...
#    done in 23.8 seconds
# Dowloading Lkn_1886_Tome_I_Part_3.pdf...
#    done in 12.7 seconds
# Dowloading Lkn_1886_Tome_I_Part_4.pdf...
#    done in 10.1 seconds
# Dowloading Lkn_1886_Tome_I_Part_5.pdf...
#    done in 9.2 seconds
# Dowloading Lkn_1886_Tome_I_Part_6.pdf...
#    done in 8.7 seconds
# Dowloading Lkn_1886_Tome_I_Part_7.pdf...
#    done in 1.6 seconds
# Dowloading Bxl_1887_Tome_I1_Part_1.pdf...
#    done in 11.7 seconds
# Dowloading Bxl_1887_Tome_I1_Part_2.pdf...
#    done in 12.0 seconds
# Dowloading Bxl_1887_Tome_I1_Part_3.pdf...
#    done in 10.9 seconds
# Dowloading Bxl_1887_Tome_I1_Part_4.pdf...
#    done in 10.9 seconds
# Dowloading Bxl_1887_Tome_I1_Part_5.pdf...
#    done in 16.9 seconds
# Dowloading Bxl_1887_Tome_I1_Part_6.pdf...
#    done in 25.2 seconds
# Dowloading Bxl_1887_Tome_I1_Part_7.pdf...
#    done in 12.0 seconds
# Dowloading Bxl_1887_Tome_I1_Part_8.pdf...
#    done in 4.6 seconds
# Dowloading Bxl_1887_Tome_I2_Part_1.pdf...
#    done in 11.8 seconds
# Dowloading Bxl_1887_Tome_I2_Part_10.pdf...
#    done in 9.8 seconds
# Dowloading Bxl_1887_Tome_I2_Part_11.pdf...
#    done in 10.4 seconds
# Dowloading Bxl_1887_Tome_I2_Part_12.pdf...
#    done in 3.9 seconds
# Dowloading Bxl_1887_Tome_I2_Part_2.pdf...
#    done in 15.4 seconds
# Dowloading Bxl_1887_Tome_I2_Part_3.pdf...
#    done in 19.3 seconds
# Dowloading Bxl_1887_Tome_I2_Part_4.pdf...
#    done in 19.3 seconds
# Dowloading Bxl_1887_Tome_I2_Part_5.pdf...
#    done in 17.7 seconds
# Dowloading Bxl_1887_Tome_I2_Part_6.pdf...
#    done in 13.8 seconds
# Dowloading Bxl_1887_Tome_I2_Part_7.pdf...
#    done in 13.1 seconds
# Dowloading Bxl_1887_Tome_I2_Part_8.pdf...
#    done in 12.5 seconds
# Dowloading Bxl_1887_Tome_I2_Part_9.pdf...
#    done in 13.7 seconds
# Dowloading Lkn_1887_Tome_I_Part_1.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1887_Tome_I_Part_2.pdf...
#    done in 1.6 seconds
# Dowloading Lkn_1887_Tome_I_Part_3.pdf...
#    done in 1.7 seconds
# Dowloading Lkn_1887_Tome_I_Part_4.pdf...
#    done in 1.7 seconds
# Dowloading Lkn_1887_Tome_I_Part_5.pdf...
#    done in 1.4 seconds
# Dowloading Bxl_1888_Tome_I1_Part_1.pdf...
#    done in 12.2 seconds
# Dowloading Bxl_1888_Tome_I1_Part_2.pdf...
#    done in 11.3 seconds
# Dowloading Bxl_1888_Tome_I1_Part_3.pdf...
#    done in 11.9 seconds
# Dowloading Bxl_1888_Tome_I1_Part_4.pdf...
#    done in 11.7 seconds
# Dowloading Bxl_1888_Tome_I1_Part_5.pdf...
#    done in 2.5 seconds
# Dowloading Bxl_1888_Tome_I2_Part_1.pdf...
#    done in 7.3 seconds
# Dowloading Bxl_1888_Tome_I2_Part_10.pdf...
#    done in 7.5 seconds
# Dowloading Bxl_1888_Tome_I2_Part_11.pdf...
#    done in 6.3 seconds
# Dowloading Bxl_1888_Tome_I2_Part_12.pdf...
#    done in 3.8 seconds
# Dowloading Bxl_1888_Tome_I2_Part_13.pdf...
#    done in 4.3 seconds
# Dowloading Bxl_1888_Tome_I2_Part_14.pdf...
#    done in 1.5 seconds
# Dowloading Bxl_1888_Tome_I2_Part_2.pdf...
#    done in 3.2 seconds
# Dowloading Bxl_1888_Tome_I2_Part_3.pdf...
#    done in 4.1 seconds
# Dowloading Bxl_1888_Tome_I2_Part_4.pdf...
#    done in 4.9 seconds
# Dowloading Bxl_1888_Tome_I2_Part_5.pdf...
#    done in 5.0 seconds
# Dowloading Bxl_1888_Tome_I2_Part_6.pdf...
#    done in 4.8 seconds
# Dowloading Bxl_1888_Tome_I2_Part_7.pdf...
#    done in 4.8 seconds
# Dowloading Bxl_1888_Tome_I2_Part_8.pdf...
#    done in 4.6 seconds
# Dowloading Bxl_1888_Tome_I2_Part_9.pdf...
#    done in 4.6 seconds
# Dowloading Lkn_1888_Tome_I_Part_1.pdf...
#    done in 8.9 seconds
# Dowloading Lkn_1888_Tome_I_Part_10.pdf...
#    done in 8.8 seconds
# Dowloading Lkn_1888_Tome_I_Part_11.pdf...
#    done in 10.6 seconds
# Dowloading Lkn_1888_Tome_I_Part_12.pdf...
#    done in 11.7 seconds
# Dowloading Lkn_1888_Tome_I_Part_2.pdf...
#    done in 13.8 seconds
# Dowloading Lkn_1888_Tome_I_Part_3.pdf...
#    done in 8.2 seconds
# Dowloading Lkn_1888_Tome_I_Part_4.pdf...
#    done in 8.7 seconds
# Dowloading Lkn_1888_Tome_I_Part_5.pdf...
#    done in 9.0 seconds
# Dowloading Lkn_1888_Tome_I_Part_6.pdf...
#    done in 8.8 seconds
# Dowloading Lkn_1888_Tome_I_Part_7.pdf...
#    done in 8.8 seconds
# Dowloading Lkn_1888_Tome_I_Part_8.pdf...
#    done in 8.4 seconds
# Dowloading Lkn_1888_Tome_I_Part_9.pdf...
#    done in 8.6 seconds
# Dowloading Bxl_1889_Tome_I1_Part_1.pdf...
#    done in 13.0 seconds
# Dowloading Bxl_1889_Tome_I1_Part_2.pdf...
#    done in 17.1 seconds
# Dowloading Bxl_1889_Tome_I1_Part_3.pdf...
#    done in 18.4 seconds
# Dowloading Bxl_1889_Tome_I1_Part_4.pdf...
#    done in 18.8 seconds
# Dowloading Bxl_1889_Tome_I1_Part_5.pdf...
#    done in 18.7 seconds
# Dowloading Bxl_1889_Tome_I1_Part_6.pdf...
#    done in 10.3 seconds
# Dowloading Bxl_1889_Tome_I1_Part_7.pdf...
#    done in 8.2 seconds
# Dowloading Bxl_1889_Tome_I1_Part_8.pdf...
#    done in 1.2 seconds
# Dowloading Bxl_1889_Tome_I2_Part_1.pdf...
#    done in 10.8 seconds
# Dowloading Bxl_1889_Tome_I2_Part_10.pdf...
#    done in 9.1 seconds
# Dowloading Bxl_1889_Tome_I2_Part_11.pdf...
#    done in 10.4 seconds
# Dowloading Bxl_1889_Tome_I2_Part_12.pdf...
#    done in 8.9 seconds
# Dowloading Bxl_1889_Tome_I2_Part_13.pdf...
#    done in 4.8 seconds
# Dowloading Bxl_1889_Tome_I2_Part_2.pdf...
#    done in 9.6 seconds
# Dowloading Bxl_1889_Tome_I2_Part_3.pdf...
#    done in 11.1 seconds
# Dowloading Bxl_1889_Tome_I2_Part_4.pdf...
#    done in 11.5 seconds
# Dowloading Bxl_1889_Tome_I2_Part_5.pdf...
#    done in 11.3 seconds
# Dowloading Bxl_1889_Tome_I2_Part_6.pdf...
#    done in 11.4 seconds
# Dowloading Bxl_1889_Tome_I2_Part_7.pdf...
#    done in 11.7 seconds
# Dowloading Bxl_1889_Tome_I2_Part_8.pdf...
#    done in 11.9 seconds
# Dowloading Bxl_1889_Tome_I2_Part_9.pdf...
#    done in 8.2 seconds
# Dowloading Bxl_1890_Tome_I1_Part_1.pdf...
#    done in 12.1 seconds
# Dowloading Bxl_1890_Tome_I1_Part_2.pdf...
#    done in 14.6 seconds
# Dowloading Bxl_1890_Tome_I1_Part_3.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1890_Tome_I1_Part_4.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1890_Tome_I1_Part_5.pdf...
#    done in 28.7 seconds
# Dowloading Bxl_1890_Tome_I1_Part_6.pdf...
#    done in 28.4 seconds
# Dowloading Bxl_1890_Tome_I1_Part_7.pdf...
#    done in 24.8 seconds
# Dowloading Bxl_1890_Tome_I1_Part_8.pdf...
#    done in 11.6 seconds
# Dowloading Bxl_1890_Tome_I2_Part_1.pdf...
#    done in 17.1 seconds
# Dowloading Bxl_1890_Tome_I2_Part_10.pdf...
#    done in 11.9 seconds
# Dowloading Bxl_1890_Tome_I2_Part_11.pdf...
#    done in 10.6 seconds
# Dowloading Bxl_1890_Tome_I2_Part_12.pdf...
#    done in 17.0 seconds
# Dowloading Bxl_1890_Tome_I2_Part_13.pdf...
#    done in 23.3 seconds
# Dowloading Bxl_1890_Tome_I2_Part_14.pdf...
#    done in 15.9 seconds
# Dowloading Bxl_1890_Tome_I2_Part_2.pdf...
#    done in 13.0 seconds
# Dowloading Bxl_1890_Tome_I2_Part_3.pdf...
#    done in 12.9 seconds
# Dowloading Bxl_1890_Tome_I2_Part_4.pdf...
#    done in 16.0 seconds
# Dowloading Bxl_1890_Tome_I2_Part_5.pdf...
#    done in 31.2 seconds
# Dowloading Bxl_1890_Tome_I2_Part_6.pdf...
#    done in 13.4 seconds
# Dowloading Bxl_1890_Tome_I2_Part_7.pdf...
#    done in 13.4 seconds
# Dowloading Bxl_1890_Tome_I2_Part_8.pdf...
#    done in 14.5 seconds
# Dowloading Bxl_1890_Tome_I2_Part_9.pdf...
#    done in 14.2 seconds
# Dowloading Lkn_1890_Tome_I_Part_1.pdf...
#    done in 1.9 seconds
# Dowloading Lkn_1890_Tome_I_Part_2.pdf...
#    done in 1.7 seconds
# Dowloading Lkn_1890_Tome_I_Part_3.pdf...
#    done in 1.9 seconds
# Dowloading Lkn_1890_Tome_I_Part_4.pdf...
#    done in 1.8 seconds
# Dowloading Lkn_1890_Tome_I_Part_5.pdf...
#    done in 1.6 seconds
# Dowloading Lkn_1890_Tome_I_Part_6.pdf...
#    done in 1.7 seconds
# Dowloading Lkn_1890_Tome_I_Part_7.pdf...
#    done in 0.9 seconds
# Dowloading Lkn_1890_Tome_RptAn_Part_1.pdf...
#    done in 1.5 seconds
# Dowloading Lkn_1890_Tome_RptAn_Part_2.pdf...
#    done in 1.5 seconds
# Dowloading Lkn_1890_Tome_RptAn_Part_3.pdf...
#    done in 1.4 seconds
# Dowloading Lkn_1890_Tome_RptAn_Part_4.pdf...
#    done in 1.5 seconds
# Dowloading Bxl_1891_Tome_I1_Part_1.pdf...
#    done in 14.2 seconds
# Dowloading Bxl_1891_Tome_I1_Part_2.pdf...
#    done in 12.6 seconds
# Dowloading Bxl_1891_Tome_I1_Part_3.pdf...
#    done in 13.8 seconds
# Dowloading Bxl_1891_Tome_I1_Part_4.pdf...
#    done in 21.7 seconds
# Dowloading Bxl_1891_Tome_I1_Part_5.pdf...
#    done in 18.8 seconds
# Dowloading Bxl_1891_Tome_I1_Part_6.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1891_Tome_I1_Part_7.pdf...
#    done in 15.6 seconds
# Dowloading Bxl_1891_Tome_I1_Part_8.pdf...
#    done in 13.5 seconds
# Dowloading Bxl_1891_Tome_I1_Part_9.pdf...
#    done in 7.0 seconds
# Dowloading Bxl_1891_Tome_I2_Part_1.pdf...
#    done in 22.6 seconds
# Dowloading Bxl_1891_Tome_I2_Part_10.pdf...
#    done in 18.4 seconds
# Dowloading Bxl_1891_Tome_I2_Part_11.pdf...
#    done in 13.8 seconds
# Dowloading Bxl_1891_Tome_I2_Part_12.pdf...
#    done in 10.7 seconds
# Dowloading Bxl_1891_Tome_I2_Part_13.pdf...
#    done in 19.3 seconds
# Dowloading Bxl_1891_Tome_I2_Part_14.pdf...
#    done in 10.8 seconds
# Dowloading Bxl_1891_Tome_I2_Part_2.pdf...
#    done in 13.4 seconds
# Dowloading Bxl_1891_Tome_I2_Part_3.pdf...
#    done in 10.0 seconds
# Dowloading Bxl_1891_Tome_I2_Part_4.pdf...
#    done in 13.3 seconds
# Dowloading Bxl_1891_Tome_I2_Part_5.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1891_Tome_I2_Part_6.pdf...
#    done in 25.5 seconds
# Dowloading Bxl_1891_Tome_I2_Part_7.pdf...
#    done in 18.2 seconds
# Dowloading Bxl_1891_Tome_I2_Part_8.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1891_Tome_I2_Part_9.pdf...
#    done in 12.4 seconds
# Dowloading Lkn_1891_Tome_I_Part_1.pdf...
#    done in 7.8 seconds
# Dowloading Lkn_1891_Tome_I_Part_2.pdf...
#    done in 7.3 seconds
# Dowloading Lkn_1891_Tome_I_Part_3.pdf...
#    done in 9.2 seconds
# Dowloading Lkn_1891_Tome_I_Part_4.pdf...
#    done in 8.2 seconds
# Dowloading Lkn_1891_Tome_I_Part_5.pdf...
#    done in 5.9 seconds
# Dowloading Bxl_1892_Tome_I1_Part_1.pdf...
#    done in 13.7 seconds
# Dowloading Bxl_1892_Tome_I1_Part_2.pdf...
#    done in 13.7 seconds
# Dowloading Bxl_1892_Tome_I1_Part_3.pdf...
#    done in 14.4 seconds
# Dowloading Bxl_1892_Tome_I1_Part_4.pdf...
#    done in 18.1 seconds
# Dowloading Bxl_1892_Tome_I1_Part_5.pdf...
#    done in 21.8 seconds
# Dowloading Bxl_1892_Tome_I1_Part_6.pdf...
#    done in 26.4 seconds
# Dowloading Bxl_1892_Tome_I1_Part_7.pdf...
#    done in 20.1 seconds
# Dowloading Bxl_1892_Tome_I1_Part_8.pdf...
#    done in 25.5 seconds
# Dowloading Bxl_1892_Tome_I1_Part_9.pdf...
#    done in 12.0 seconds
# Dowloading Bxl_1892_Tome_I2_Part_1.pdf...
#    done in 13.3 seconds
# Dowloading Bxl_1892_Tome_I2_Part_10.pdf...
#    done in 8.2 seconds
# Dowloading Bxl_1892_Tome_I2_Part_11.pdf...
#    done in 9.9 seconds
# Dowloading Bxl_1892_Tome_I2_Part_12.pdf...
#    done in 4.0 seconds
# Dowloading Bxl_1892_Tome_I2_Part_2.pdf...
#    done in 14.5 seconds
# Dowloading Bxl_1892_Tome_I2_Part_3.pdf...
#    done in 11.9 seconds
# Dowloading Bxl_1892_Tome_I2_Part_4.pdf...
#    done in 11.8 seconds
# Dowloading Bxl_1892_Tome_I2_Part_5.pdf...
#    done in 13.2 seconds
# Dowloading Bxl_1892_Tome_I2_Part_6.pdf...
#    done in 14.3 seconds
# Dowloading Bxl_1892_Tome_I2_Part_7.pdf...
#    done in 12.3 seconds
# Dowloading Bxl_1892_Tome_I2_Part_8.pdf...
#    done in 13.0 seconds
# Dowloading Bxl_1892_Tome_I2_Part_9.pdf...
#    done in 12.6 seconds
# Dowloading Lkn_1892_Tome_I_Part_1.pdf...
#    done in 8.3 seconds
# Dowloading Lkn_1892_Tome_I_Part_2.pdf...
#    done in 7.5 seconds
# Dowloading Lkn_1892_Tome_I_Part_3.pdf...
#    done in 11.1 seconds
# Dowloading Lkn_1892_Tome_I_Part_4.pdf...
#    done in 15.2 seconds
# Dowloading Lkn_1892_Tome_I_Part_5.pdf...
#    done in 7.8 seconds
# Dowloading Bxl_1893_Tome_I1_Part_1.pdf...
#    done in 35.9 seconds
# Dowloading Bxl_1893_Tome_I1_Part_2.pdf...
#    done in 16.1 seconds
# Dowloading Bxl_1893_Tome_I1_Part_3.pdf...
#    done in 16.9 seconds
# Dowloading Bxl_1893_Tome_I1_Part_4.pdf...
#    done in 14.1 seconds
# Dowloading Bxl_1893_Tome_I1_Part_5.pdf...
#    done in 12.9 seconds
# Dowloading Bxl_1893_Tome_I1_Part_6.pdf...
#    done in 14.6 seconds
# Dowloading Bxl_1893_Tome_I1_Part_7.pdf...
#    done in 11.6 seconds
# Dowloading Bxl_1893_Tome_I1_Part_8.pdf...
#    done in 13.8 seconds
# Dowloading Bxl_1893_Tome_II2_Part_1.pdf...
#    done in 12.0 seconds
# Dowloading Bxl_1893_Tome_II2_Part_10.pdf...
#    done in 12.1 seconds
# Dowloading Bxl_1893_Tome_II2_Part_2.pdf...
#    done in 10.4 seconds
# Dowloading Bxl_1893_Tome_II2_Part_3.pdf...
#    done in 13.3 seconds
# Dowloading Bxl_1893_Tome_II2_Part_4.pdf...
#    done in 12.2 seconds
# Dowloading Bxl_1893_Tome_II2_Part_5.pdf...
#    done in 14.2 seconds
# Dowloading Bxl_1893_Tome_II2_Part_6.pdf...
#    done in 12.8 seconds
# Dowloading Bxl_1893_Tome_II2_Part_7.pdf...
#    done in 13.3 seconds
# Dowloading Bxl_1893_Tome_II2_Part_8.pdf...
#    done in 10.1 seconds
# Dowloading Bxl_1893_Tome_II2_Part_9.pdf...
#    done in 14.5 seconds
# Dowloading Lkn_1893_Tome_I_Part_1.pdf...
#    done in 4.6 seconds
# Dowloading Lkn_1893_Tome_I_Part_2.pdf...
#    done in 3.2 seconds
# Dowloading Lkn_1893_Tome_I_Part_3.pdf...
#    done in 2.9 seconds
# Wall time: 2h 29min 25s

# %% [markdown]
# ## Vérifier si les 3 premiers PDFs ont été téléchargés

# %%
check(pdf_path, urls[:700])
# Out:
# 700 PDFs found on 700!
